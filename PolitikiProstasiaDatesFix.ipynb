# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import ast
import time
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df =pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/PolitikiProstasiaArticles07042021.tsv", sep='\t')

# %%
df
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  https://www.civilprotection.gr/el/ishyres-vroh...
# 1             1  ...  https://www.civilprotection.gr/el/simantika-th...
# 2             2  ...  https://www.civilprotection.gr/el/simantika-th...
# 3             3  ...  https://www.civilprotection.gr/el/simantika-th...
# 4             4  ...  https://www.civilprotection.gr/el/simantika-th...
# ..          ...  ...                                                ...
# 544         544  ...  https://www.civilprotection.gr/el/simantika-th...
# 545         545  ...  https://www.civilprotection.gr/el/simantika-th...
# 546         546  ...  https://www.civilprotection.gr/el/emfasi-stin-...
# 547         547  ...  https://www.civilprotection.gr/el/simantika-th...
# 548         548  ...  https://www.civilprotection.gr/el/simantika-th...
#
# [549 rows x 5 columns]

# %%
df['date'] = df['date'].str.replace('Αθήνα,', '')

# %%
df
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  https://www.civilprotection.gr/el/ishyres-vroh...
# 1             1  ...  https://www.civilprotection.gr/el/simantika-th...
# 2             2  ...  https://www.civilprotection.gr/el/simantika-th...
# 3             3  ...  https://www.civilprotection.gr/el/simantika-th...
# 4             4  ...  https://www.civilprotection.gr/el/simantika-th...
# ..          ...  ...                                                ...
# 544         544  ...  https://www.civilprotection.gr/el/simantika-th...
# 545         545  ...  https://www.civilprotection.gr/el/simantika-th...
# 546         546  ...  https://www.civilprotection.gr/el/emfasi-stin-...
# 547         547  ...  https://www.civilprotection.gr/el/simantika-th...
# 548         548  ...  https://www.civilprotection.gr/el/simantika-th...
#
# [549 rows x 5 columns]

# %%
#Λάθος ημερομηνία
#df=df.drop([548], axis=0)

# %%
df['date'] = df['date'].str.replace('Ιανουαρίου', '-01-')
df['date'] = df['date'].str.replace('Φεβρουαρίου', '-02-')
df['date'] = df['date'].str.replace('Μαρτίου', '-03-')
df['date'] = df['date'].str.replace('Απριλίου', '-04-')
df['date'] = df['date'].str.replace('Μαΐου', '-05-')
df['date'] = df['date'].str.replace('Ιουνίου', '-06-')
df['date'] = df['date'].str.replace('Ιουλίου', '-07-')
df['date'] = df['date'].str.replace('Αυγούστου', '-08-')
df['date'] = df['date'].str.replace('Σεπτεμβρίου', '-09-')
df['date'] = df['date'].str.replace('Οκτωβρίου', '-10-')
df['date'] = df['date'].str.replace('Νοεμβρίου', '-11-')
df['date'] = df['date'].str.replace('Δεκεμβρίου', '-12-')

# %%
df['date'] = df['date'].str.replace(' ', '')

# %%
df
# Out:
#      Unnamed: 0  ...                                                url
# 0             0  ...  https://www.civilprotection.gr/el/ishyres-vroh...
# 1             1  ...  https://www.civilprotection.gr/el/simantika-th...
# 2             2  ...  https://www.civilprotection.gr/el/simantika-th...
# 3             3  ...  https://www.civilprotection.gr/el/simantika-th...
# 4             4  ...  https://www.civilprotection.gr/el/simantika-th...
# ..          ...  ...                                                ...
# 544         544  ...  https://www.civilprotection.gr/el/simantika-th...
# 545         545  ...  https://www.civilprotection.gr/el/simantika-th...
# 546         546  ...  https://www.civilprotection.gr/el/emfasi-stin-...
# 547         547  ...  https://www.civilprotection.gr/el/simantika-th...
# 548         548  ...  https://www.civilprotection.gr/el/simantika-th...
#
# [549 rows x 5 columns]

# %%
from datetime import timedelta
from datetime import datetime as dt

df['date'] = pd.to_datetime(df['date'], dayfirst=True, errors='coerce')
df[10:40]
# Out:
#     Unnamed: 0  ...                                                url
# 10          10  ...  https://www.civilprotection.gr/el/simantika-th...
# 11          11  ...  https://www.civilprotection.gr/el/simantika-th...
# 12          12  ...  https://www.civilprotection.gr/el/stin-kerkyra...
# 13          13  ...  https://www.civilprotection.gr/el/sti-rodo-met...
# 14          14  ...  https://www.civilprotection.gr/el/simantika-th...
# 15          15  ...  https://www.civilprotection.gr/el/simantika-th...
# 16          16  ...  https://www.civilprotection.gr/el/nea-ektakti-...
# 17          17  ...  https://www.civilprotection.gr/el/simantika-th...
# 18          18  ...  https://www.civilprotection.gr/el/simantika-th...
# 19          19  ...  https://www.civilprotection.gr/el/simantika-th...
# 20          20  ...  https://www.civilprotection.gr/el/simantika-th...
# 21          21  ...  https://www.civilprotection.gr/el/simantika-th...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# title                 object
# date          datetime64[ns]
# body                  object
# url                   object
# dtype: object

# %%
df.to_csv("/content/gdrive/My Drive/Colab Notebooks/PolitikiProstasiaFinalFixed07042021.tsv", sep='\t')

# %%
#df_sorted= df.sort_values(by=['date'], inplace=True, ascending=False)

# %%
#df_sorted
