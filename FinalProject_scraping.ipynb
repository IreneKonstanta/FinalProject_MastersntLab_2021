# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import ast
import time

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}

# %%
response = requests.get("https://www.civilprotection.gr/el/announcements", headers=headers)

# %%
doc = BeautifulSoup(response.text)

# %%
#doc

# %%
links = doc.select("h2 a") 
links
# Out:
# [<a href="/el/simantika-themata/me-dyo-canadair-cl-415-i-ellada-syndramei-tin-kypro">Με δύο Canadair CL-415 η Ελλάδα συνδράμει την Κύπρο</a>,
#  <a href="/el/simantika-themata/poly-ypsilos-kindynos-pyrkagias-katigoria-kindynoy-4-gia-ayrio-kyriaki-04-ioylioy">Πολύ υψηλός κίνδυνος πυρκαγιάς (κατηγορία κινδύνου 4)  για αύριο, Κυριακή 04 Ιουλίου 2021</a>,
#  <a href="/el/simantika-themata/enimerosi-diapisteymenon-syntakton-apo-ton-yfypoyrgo-politikis-prostasias-6"> Ενημέρωση διαπιστευμένων συντακτών από τον Υφυπουργό Πολιτικής Προστασίας &amp; Διαχείρισης Κρίσεων Ν. Χαρδαλιά και τους καθηγητές Β.Παπαευαγγέλου και  Γκ. Μαγιορκίνη</a>,
#  <a href="/el/simantika-themata/poly-ypsilos-kindynos-pyrkagias-katigoria-kindynoy-4-gia-ayrio-paraskeyi-02">Πολύ υψηλός κίνδυνος πυρκαγιάς (κατηγορία κινδύνου 4)  για αύριο, Παρασκευή 02 Ιουλίου 2021</a>,
# ...

# %%
urls = [link['href'] for link in links]
urls
# Out:
# ['/el/simantika-themata/me-dyo-canadair-cl-415-i-ellada-syndramei-tin-kypro',
#  '/el/simantika-themata/poly-ypsilos-kindynos-pyrkagias-katigoria-kindynoy-4-gia-ayrio-kyriaki-04-ioylioy',
#  '/el/simantika-themata/enimerosi-diapisteymenon-syntakton-apo-ton-yfypoyrgo-politikis-prostasias-6',
#  '/el/simantika-themata/poly-ypsilos-kindynos-pyrkagias-katigoria-kindynoy-4-gia-ayrio-paraskeyi-02',
#  '/el/simantika-themata/poly-ypsilos-kindynos-pyrkagias-katigoria-kindynoy-4-gia-ayrio-pempti-01-ioylioy',
#  '/el/anodos-tis-thermokrasias-tis-epomenes-imeres-se-olokliri-ti-hora',
#  '/el/enimerosi-diapisteymenon-syntakton-apo-ton-yfypoyrgo-politikis-prostasias-diaheirisis-kriseon-n',
#  '/el/aisthiti-anodos-tis-thermokrasias-tis-epomenes-imeres-sto-megalytero-meros-tis-horas',
#  '/el/simantika-themata/enimerosi-syntakton-apo-yfypoyrgo-politikis-prostasias-diaheirisis-kriseon-n-4',
#  '/el/simantika-themata/stin-ippokrateio-politeia-o-nikos-hardalias-prohora-ergo-dianoixis-odon']

# %%
titles = [link.text for link in links]
titles
# Out:
# ['Με δύο Canadair CL-415 η Ελλάδα συνδράμει την Κύπρο',
#  'Πολύ υψηλός κίνδυνος πυρκαγιάς (κατηγορία κινδύνου 4)  για αύριο, Κυριακή 04 Ιουλίου 2021',
#  ' Ενημέρωση διαπιστευμένων συντακτών από τον Υφυπουργό Πολιτικής Προστασίας & Διαχείρισης Κρίσεων Ν. Χαρδαλιά και τους καθηγητές Β.Παπαευαγγέλου και  Γκ. Μαγιορκίνη',
#  'Πολύ υψηλός κίνδυνος πυρκαγιάς (κατηγορία κινδύνου 4)  για αύριο, Παρασκευή 02 Ιουλίου 2021',
#  'Πολύ υψηλός κίνδυνος πυρκαγιάς (κατηγορία κινδύνου 4)  για αύριο Πέμπτη 01 Ιουλίου 2021',
#  'Άνοδος της θερμοκρασίας τις επόμενες ημέρες σε ολόκληρη τη χώρα',
#  'Ενημέρωση διαπιστευμένων συντακτών από τον Υφυπουργό Πολιτικής Προστασίας & Διαχείρισης Κρίσεων Ν. Χαρδαλιά και τους καθηγητές Β.Παπαευαγγέλου και  Γκ. Μαγιορκίνη',
#  'Αισθητή άνοδος της θερμοκρασίας τις επόμενες ημέρες στο μεγαλύτερο μέρος της χώρας',
# ...

# %%
from bs4 import BeautifulSoup
import requests
import time

headers = {'user-agent': 'my-app/0.0.1'}
PAUSE_TIME = 3.5

def get_text(url):
    r = requests.get(url, headers = headers)
    time.sleep(PAUSE_TIME)
    s = BeautifulSoup(r.content, 'html.parser')
    link = s.find("h2 a")
    
    return([s, link])

# %%
scraped_links = []
titles = []
counter = 0
base_url = "https://www.civilprotection.gr/el/announcements?page="
for i in range(1,56):
    url = base_url + str(i)
    #print(url)
    page = requests.get(url, headers = headers)
    s = BeautifulSoup(page.content, 'html.parser')
    #print(s)
    links = s.select("h2 a")
    links = set(links)
    
    url = [link['href'] for link in links]
    
    #title = [link.text for link in links]
    
    
    print(url)

    for l in url:
        link = l
        print(l)
        scraped_links.append(l)


    
    # Τυπώνει το νούμερο των links που είναι scraped
print(len(scraped_links)) 

#scraped_links = (set(scraped_links))
# Out:
# ['/el/ishyres-vrohes-kai-kataigides-provlepontai-simera-paraskeyi-kai-ayrio-savvato-poy-tha-synodeyontai', '/el/simantika-themata/nikos-hardalias-apo-ti-thessaloniki-apo-deytera-xekinoyn-oi-katharismoi', '/el/simantika-themata/epiheirisi-dryades-apo-tin-politiki-prostasia-gia-tin-antipyriki-thorakisi-tis', '/el/simantika-themata/antipyriki-periodos-2021-synenteyxi-typoy-o-shediasmos-kai-oi-draseis-tis', '/el/simantika-themata/den-paizoyme-me-ti-fotia-giati-i-fotia-den-paizei-mazi-mas-nea-enimerotiki', '/el/simantika-themata/enimerosi-diapisteymenon-syntakton-apo-ton-ypoyrgo-ygeias-vasili-kikilia-kai-ton', '/el/enimerosi-syntakton-apo-yfypoyrgo-politikis-prostasias-diaheirisis-kriseon-n-hardalia-kai-kathigites', '/el/simantika-themata/anadimosieysi-deltioy-typoy-pyrosvestikoy-somatos-shetika-me-ti-dienergeia-askisis', '/el/sti-thessaloniki-ayrio-o-nikos-hardalias-xekinoyn-oi-katharismoi-antipyrikis-thorakisis-sto-dasos', '/el/simantika-themata/sto-tatoi-simera-o-nikos-hardalias-prohor
# ...

# %%
import pandas as pd
df = pd.DataFrame(scraped_links, columns= ['url'])

# %%
df
# Out:
#                                                    url
# 0    /el/ishyres-vrohes-kai-kataigides-provlepontai...
# 1    /el/simantika-themata/nikos-hardalias-apo-ti-t...
# 2    /el/simantika-themata/epiheirisi-dryades-apo-t...
# 3    /el/simantika-themata/antipyriki-periodos-2021...
# 4    /el/simantika-themata/den-paizoyme-me-ti-fotia...
# ..                                                 ...
# 545  /el/simantika-themata/tehnikos-symvoylos-tis-g...
# 546  /el/emfasi-stin-prolipsi-syskepsi-toy-ggpp-nik...
# 547  /el/simantika-themata/episkepsi-ggpp-nikoy-har...
# 548  /el/simantika-themata/stin-ptolemaida-stin-koz...
# 549  /el/simantika-themata/sto-loyxemvoyrgo-o-ggpp-...
#
# [550 rows x 1 columns]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df
# Out:
#                                                    url
# 0    https://www.civilprotection.gr/el/ishyres-vroh...
# 1    https://www.civilprotection.gr/el/simantika-th...
# 2    https://www.civilprotection.gr/el/simantika-th...
# 3    https://www.civilprotection.gr/el/simantika-th...
# 4    https://www.civilprotection.gr/el/simantika-th...
# ..                                                 ...
# 545  https://www.civilprotection.gr/el/simantika-th...
# 546  https://www.civilprotection.gr/el/emfasi-stin-...
# 547  https://www.civilprotection.gr/el/simantika-th...
# 548  https://www.civilprotection.gr/el/simantika-th...
# 549  https://www.civilprotection.gr/el/simantika-th...
#
# [550 rows x 1 columns]

# %%
df.to_csv("/content/gdrive/My Drive/Colab Notebooks/PolitikiProstasia07042021.tsv", sep='\t')

# %%
df =pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/PolitikiProstasia07042021.tsv", sep='\t')

# %%
df
# Out:
#      Unnamed: 0                                                url
# 0             0  https://www.civilprotection.gr/el/ishyres-vroh...
# 1             1  https://www.civilprotection.gr/el/simantika-th...
# 2             2  https://www.civilprotection.gr/el/simantika-th...
# 3             3  https://www.civilprotection.gr/el/simantika-th...
# 4             4  https://www.civilprotection.gr/el/simantika-th...
# ..          ...                                                ...
# 545         545  https://www.civilprotection.gr/el/simantika-th...
# 546         546  https://www.civilprotection.gr/el/emfasi-stin-...
# 547         547  https://www.civilprotection.gr/el/simantika-th...
# 548         548  https://www.civilprotection.gr/el/simantika-th...
# 549         549  https://www.civilprotection.gr/el/simantika-th...
#
# [550 rows x 2 columns]
